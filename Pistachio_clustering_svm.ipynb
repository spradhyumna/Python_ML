# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
pistachio=pd.read_csv("E:/Data science/python/New folder/Pistachio_16_Features_Dataset.csv")
pistachio
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0      63391  1568.4050    390.3396    236.7461        0.7951  284.0984
# 1      68358  1942.1870    410.8594    234.7525        0.8207  295.0188
# 2      73589  1246.5380    452.3630    220.5547        0.8731  306.0987
# 3      71106  1445.2610    429.5291    216.0765        0.8643  300.8903
# 4      80087  1251.5240    469.3783    220.9344        0.8823  319.3273
# ...      ...        ...         ...         ...           ...       ...
# 2143   85983  1157.1160    444.3447    248.8627        0.8284  330.8730
# 2144   85691  2327.3459    439.8794    278.9297        0.7732  330.3107
# 2145  101136  1255.6190    475.2161    271.3299        0.8210  358.8459
# 2146   97409  1195.2150    452.1823    274.5764        0.7945  352.1718
# 2147   78466  2356.9080    445.9131    258.5125        0.8148  316.0791
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
pistachio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148 entries, 0 to 2147
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           2148 non-null   int64
#  1   PERIMETER      2148 non-null   float64
#  2   MAJOR_AXIS     2148 non-null   float64
#  3   MINOR_AXIS     2148 non-null   float64
#  4   ECCENTRICITY   2148 non-null   float64
#  5   EQDIASQ        2148 non-null   float64
#  6   SOLIDITY       2148 non-null   float64
#  7   CONVEX_AREA    2148 non-null   int64
#  8   EXTENT         2148 non-null   float64
#  9   ASPECT_RATIO   2148 non-null   float64
#  10  ROUNDNESS      2148 non-null   float64
#  11  COMPACTNESS    2148 non-null   float64
#  12  SHAPEFACTOR_1  2148 non-null   float64
#  13  SHAPEFACTOR_2  2148 non-null   float64
#  14  SHAPEFACTOR_3  2148 non-null   float64
#  15  SHAPEFACTOR_4  2148 non-null   float64
#  16  Class          2148 non-null   object
# ...

# %%
pistachio.isnull().sum()
# Out:
# AREA             0
# PERIMETER        0
# MAJOR_AXIS       0
# MINOR_AXIS       0
# ECCENTRICITY     0
# EQDIASQ          0
# SOLIDITY         0
# CONVEX_AREA      0
# EXTENT           0
# ASPECT_RATIO     0
# ROUNDNESS        0
# COMPACTNESS      0
# SHAPEFACTOR_1    0
# SHAPEFACTOR_2    0
# SHAPEFACTOR_3    0
# SHAPEFACTOR_4    0
# Class            0
# dtype: int64

# %%
pistachio['Class'].unique()
# Out:
# array(['Kirmizi_Pistachio', 'Siit_Pistachio'], dtype=object)

# %%
pistachio_0=pistachio[pistachio['Class']=="Kirmizi_Pistachio"]
pistachio_1=pistachio[pistachio['Class']=="Siit_Pistachio"]

# %%
pistachio_0
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0     63391   1568.405    390.3396    236.7461        0.7951  284.0984
# 1     68358   1942.187    410.8594    234.7525        0.8207  295.0188
# 2     73589   1246.538    452.3630    220.5547        0.8731  306.0987
# 3     71106   1445.261    429.5291    216.0765        0.8643  300.8903
# 4     80087   1251.524    469.3783    220.9344        0.8823  319.3273
# ...     ...        ...         ...         ...           ...       ...
# 1227  53446   1814.176    379.4000    191.5850        0.8631  260.8631
# 1228  60008    935.789    351.9654    221.9567        0.7761  276.4138
# 1229  60847   1760.171    371.3661    230.1940        0.7847  278.3394
# 1230  82017   2699.074    426.5246    273.5291        0.7673  323.1521
# 1231  52600   1148.283    361.6876    193.2737        0.8453  258.7903
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
pistachio_1
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 1232   77869  1853.8840    421.2526    240.8186        0.8205  314.8744
# 1233   94948  1184.8521    456.3920    267.6631        0.8100  347.6946
# 1234   92639  1792.0270    456.4867    275.1674        0.7979  343.4409
# 1235   84309  1524.9170    442.2157    246.1724        0.8307  327.6363
# 1236   74673  1955.6490    450.7327    237.1064        0.8505  308.3450
# ...      ...        ...         ...         ...           ...       ...
# 2143   85983  1157.1160    444.3447    248.8627        0.8284  330.8730
# 2144   85691  2327.3459    439.8794    278.9297        0.7732  330.3107
# 2145  101136  1255.6190    475.2161    271.3299        0.8210  358.8459
# 2146   97409  1195.2150    452.1823    274.5764        0.7945  352.1718
# 2147   78466  2356.9080    445.9131    258.5125        0.8148  316.0791
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=pistachio_0,x=pistachio_0['MAJOR_AXIS'],y=pistachio_0['MINOR_AXIS'],color='red',marker='p',s=80)
sns.scatterplot(data=pistachio_1,x=pistachio_1['MAJOR_AXIS'],y=pistachio_1['MINOR_AXIS'],color='green',marker='X',s=80)
# Out:
# <AxesSubplot:xlabel='MAJOR_AXIS', ylabel='MINOR_AXIS'>

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=pistachio_0,x=pistachio_0['AREA'],y=pistachio_0['PERIMETER'],color='red',marker='p',s=80)
sns.scatterplot(data=pistachio_1,x=pistachio_1['AREA'],y=pistachio_1['PERIMETER'],color='green',marker='X',s=80)
# Out:
# <AxesSubplot:xlabel='AREA', ylabel='PERIMETER'>

# %%
pistachio_0.corr()
# Out:
#                    AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# AREA           1.000000   0.086780    0.827042    0.733120     -0.054306
# PERIMETER      0.086780   1.000000    0.109036    0.377801     -0.291654
# MAJOR_AXIS     0.827042   0.109036    1.000000    0.366372      0.401468
# MINOR_AXIS     0.733120   0.377801    0.366372    1.000000     -0.683052
# ECCENTRICITY  -0.054306  -0.291654    0.401468   -0.683052      1.000000
# EQDIASQ        0.997551   0.083102    0.822337    0.737240     -0.061619
# SOLIDITY       0.383230  -0.675571    0.276831   -0.116520      0.370030
# CONVEX_AREA    0.936388   0.355681    0.785757    0.846517     -0.210608
# EXTENT         0.341318  -0.393614    0.213055    0.041218      0.156707
# ASPECT_RATIO  -0.145560  -0.262682    0.360318   -0.721478      0.946427
# ROUNDNESS      0.258554  -0.896953    0.172884   -0.087658      0.237015
# COMPACTNESS    0.290218  -0.041014   -0.288323    0.627190     -0.784979
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(pistachio_0.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
pistachio.replace(to_replace="Kirmizi_Pistachio",value=1,inplace=True)
pistachio.replace(to_replace="Siit_Pistachio",value=2,inplace=True)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
x=pistachio.drop(['Class','ECCENTRICITY','SHAPEFACTOR_1','SHAPEFACTOR_2'],axis=1)
y=pistachio['Class']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.35650743, 0.37435926, 0.31583158, ..., 0.62652401, 0.55716912,
#         0.66825145],
#        [0.40923567, 0.57143035, 0.40842093, ..., 0.60238865, 0.53125   ,
#         0.74484945],
#        [0.46476645, 0.20465959, 0.59569329, ..., 0.49937795, 0.42518382,
#         0.84178553],
#        ...,
#        [0.75719745, 0.20944741, 0.69881095, ..., 0.69445136, 0.63161765,
#         0.99920761],
#        [0.7176327 , 0.17760029, 0.59487794, ..., 0.75342125, 0.69852941,
#         0.99973587],
#        [0.51653928, 0.79008593, 0.56659008, ..., 0.57924857, 0.50698529,
#         0.65055468]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.30,random_state=100)

# %%
svc = SVC(kernel='linear',random_state=100)

# %%
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=100)

# %%
print(svc.score(x_train,y_train))
print(svc.score(x_test,y_test))
# Out:
# 0.8689288090485695
# 0.8790697674418605

# %%
y_pred=svc.predict(x_test)

# %%
y_pred

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[344  45]
#  [ 33 223]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.91      0.88      0.90       389
#            2       0.83      0.87      0.85       256
#
#     accuracy                           0.88       645
#    macro avg       0.87      0.88      0.87       645
# weighted avg       0.88      0.88      0.88       645

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 87.90697674418605

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
from sklearn.metrics import confusion_matrix
y_pred=knn.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[357,  32],
#        [ 77, 179]], dtype=int64)

# %%
import seaborn as sns
plt.figure()
sns.heatmap(cm,annot=True)
plt.xlabel('prdicted')
plt.ylabel('Truth')
# Out:
# Text(13.060000000000002, 0.5, 'Truth')

# %% [markdown]
# # Finding Best Parameters

# %%
from sklearn.svm import SVC
grid = {
    'C':[0.1,1,10],
    'kernel' : ["poly","rbf"],
    'degree' : [1,3]}
svx=SVC()

# %%
grid=GridSearchCV(svx,param_grid=grid,cv=5,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10], 'degree': [1, 3],
#                          'kernel': ['poly', 'rbf']})

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'C': 10, 'degree': 1, 'kernel': 'rbf'}
# SVC(C=10, degree=1)

# %%
grid_predictions = grid.predict(x_test)

# %%
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.88      0.90       389
#            2       0.83      0.88      0.86       256
#
#     accuracy                           0.88       645
#    macro avg       0.88      0.88      0.88       645
# weighted avg       0.89      0.88      0.88       645

# %%
svc1 = SVC(kernel='rbf',C=10,degree=1,random_state=100)
svc1.fit(x_train,y_train)
# Out:
# SVC(C=10, degree=1, random_state=100)

# %%
print(svc1.score(x_train,y_train))
print(svc1.score(x_test,y_test))
# Out:
# 0.8915502328675982
# 0.8837209302325582

# %%
y_pred_1=svc1.predict(x_test)

# %%
print(confusion_matrix(y_test,y_pred_1))
# Out:
# [[344  45]
#  [ 30 226]]

# %%
print(classification_report(y_test,y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.88      0.90       389
#            2       0.83      0.88      0.86       256
#
#     accuracy                           0.88       645
#    macro avg       0.88      0.88      0.88       645
# weighted avg       0.89      0.88      0.88       645

# %%
print(accuracy_score(y_test,y_pred_1)*100)
# Out:
# 88.37209302325581
